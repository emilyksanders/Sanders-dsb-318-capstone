# %%
# cut from eda

# %%
# Plot a histogram of it
plt.figure(figsize = (8, 6));
plt.hist(meyer['w1kessler6_i']**(1/2), bins = 'auto', color = 'purple');
plt.title(f'Square Root of Kessler Scores', size = 24);
plt.xlabel('Range from 0-5 (theoretically ~5.5)', size = 20);
# plt.ylabel('Frequency', size = 20);
plt.xticks(size = 16);
plt.yticks(size = 16);
plt.tight_layout();
# plt.savefig('../03_images/99_report_images/histogram_of_sqrt_kessler_scores_for_pp.png')

# %%
# Plot a histogram of it
plt.figure(figsize = (8, 6));
plt.hist(meyer['w1kessler6_i'], bins = 'auto', color = 'purple');
plt.title(f'Raw Kessler Scores', size = 24);
plt.xlabel('Range from 0-24 (theoretically 30)', size = 20);
plt.ylabel('Frequency', size = 20);
plt.xticks(size = 16);
plt.yticks(size = 16);
plt.tight_layout();
# plt.savefig('../03_images/99_report_images/histogram_of_raw_kessler_scores_for_pp.png')

# %%
# QQplot of raw kessler
sm.qqplot(meyer['w1kessler6_i'], line='45', alpha = 0.5, 
          markerfacecolor = 'purple', markeredgecolor = 'purple');
plt.title(f'QQ-Plot of Kessler Scores', size = 24);
plt.xlabel('Theoretical Quantiles', size = 20);
plt.ylabel('Sample Quantiles', size = 20);
plt.xticks(size = 14);
plt.yticks(size = 14);
plt.tight_layout();
# plt.savefig('../03_images/99_report_images/qqplot_raw_kessler_for_pp.png')

# %%
# QQplot of the square root
sm.qqplot((meyer['w1kessler6_i']**0.5), line='45', alpha = 0.5, 
          markerfacecolor = 'purple', markeredgecolor = 'purple');
plt.title(f'QQ-Plot of SQRT Kessler Scores', size = 24);
plt.xlabel('Theoretical Quantiles', size = 20);
plt.ylabel('Sample Quantiles', size = 20);
plt.xticks(size = 14);
plt.yticks(size = 14);
plt.tight_layout();
# plt.savefig('../03_images/99_report_images/qqplot_sqrt_kessler_for_pp.png')
